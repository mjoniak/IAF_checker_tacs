# %%
from main import calculate_iaf, draw_plot
config = {
    "eeg_file_type": "vhdr",
    "crop_data": {
        "beginning": 0, 
        "end": 100
    }, 
    "iaf_range": [7, 14],
    "channels": ["O1", "O2", "Pz", "P3", "P4"],
    "psd_draw_range": {"min": 2, "max": 30},
}

def draw_iaf(file_name):
    iaf, certainty, psds, freqs = calculate_iaf(file_name=file_name, config=config)
    return draw_plot(iaf=iaf, certainty=certainty, psds=psds, freqs=freqs, participant_data='')

draw_iaf("tacs/pilot_1/test_closed.vhdr")

# %%
draw_iaf("tacs/pilot_1/cloosee.vhdr")
